# %%
import pandas as pd

# %%
songs = pd.read_csv('data/songs.csv')

# %%
x = songs.drop(['Popularity'], axis = 1)

# %%
y = songs['Popularity']

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
x_train.describe()
# Out:
#              Index  Beats Per Minute (BPM)       Energy  Loudness (dB)  \
# count  1386.000000             1386.000000  1386.000000    1386.000000
# mean    997.313853              119.826118    59.413420      -9.094517
# std     577.096931               28.670959    22.060928       3.731669
# min       1.000000               15.000000     3.000000     -27.000000
# 25%     501.250000               99.000000    43.000000     -11.000000
# 50%    1004.500000              119.000000    61.000000      -9.000000
# 75%    1504.750000              135.000000    77.000000      -6.000000
# max    1994.000000              305.000000   100.000000      -2.000000
#
#           Liveness  Length (Duration)  Acousticness  Speechiness          Age
# count  1386.000000        1386.000000   1386.000000   1386.00000  1386.000000
# mean     18.974747         264.391775     29.160173      5.02381    28.633478
# std      16.715978          99.149569     29.429331      4.43877    16.069789
# min       2.000000          93.000000      0.000000      2.00000     2.000000
# 25%       9.000000         212.000000      3.000000      3.00000    14.000000
# 50%      12.000000         246.000000     18.000000      4.00000    28.000000
# 75%      22.750000         290.000000     51.000000      5.00000    43.000000
# max      98.000000        1412.000000     98.000000     46.00000    64.000000

# %%
x_test.describe()
# Out:
#              Index  Beats Per Minute (BPM)      Energy  Loudness (dB)  \
# count   595.000000              595.000000  595.000000     595.000000
# mean    993.057143              121.200000   60.171429      -8.840336
# std     575.181564               28.610916   22.455812       3.456276
# min       3.000000               37.000000    5.000000     -21.000000
# 25%     485.000000              100.500000   42.000000     -11.000000
# 50%     968.000000              119.000000   61.000000      -8.000000
# 75%    1475.000000              137.500000   80.000000      -6.000000
# max    1993.000000              197.000000   99.000000      -2.000000
#
#          Liveness  Length (Duration)  Acousticness  Speechiness         Age
# count  595.000000         595.000000    595.000000   595.000000  595.000000
# mean    19.089076         258.495798     28.406723     4.919328   28.426891
# std     16.801188          80.057395     28.154922     4.348870   16.270833
# min      3.000000         102.000000      0.000000     2.000000    2.000000
# 25%      9.000000         211.500000      4.000000     3.000000   14.000000
# 50%     13.000000         243.000000     18.000000     4.000000   28.000000
# 75%     23.000000         288.500000     48.500000     5.000000   42.000000
# max     99.000000         966.000000     99.000000    55.000000   65.000000

# %%
y_train.describe()
# Out:
# count    1386.000000
# mean       59.500722
# std        14.278471
# min        13.000000
# 25%        49.000000
# 50%        62.000000
# 75%        71.000000
# max       100.000000
# Name: Popularity, dtype: float64

# %%
y_test.describe()
# Out:
# count    595.000000
# mean      59.495798
# std       14.606554
# min       11.000000
# 25%       49.500000
# 50%       62.000000
# 75%       70.000000
# max       87.000000
# Name: Popularity, dtype: float64
